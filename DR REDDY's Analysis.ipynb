# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import plotly.express as px
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data=pd.read_csv('/content/drive/MyDrive/DTL/DRREDDY.NS.csv')

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#             Date         Open         High          Low        Close  \
# 0     2019-07-25  2619.800049  2666.000000  2607.250000  2654.100098
# 1     2019-07-26  2640.050049  2714.000000  2621.699951  2704.949951
# 2     2019-07-29  2709.899902  2726.800049  2621.300049  2653.949951
# 3     2019-07-30  2648.000000  2693.500000  2549.100098  2560.000000
# 4     2019-07-31  2535.000000  2590.000000  2533.000000  2574.600098
# ...          ...          ...          ...          ...          ...
# 1230  2024-07-19  6660.000000  6718.399902  6626.299805  6636.000000
# 1231  2024-07-22  6580.000000  6780.000000  6580.000000  6770.899902
# 1232  2024-07-23  6770.000000  6884.000000  6717.000000  6865.000000
# 1233  2024-07-24  6938.899902  6938.899902  6793.250000  6820.149902
# 1234  2024-07-25  6795.000000  6874.950195  6757.049805  6853.200195
#
#         Adj Close   Volume
# 0     2571.718262   516388
# 1     2620.989746   537619
# 2     2571.572754   919633
# ...

# %%
df
# Out:
#             Date         Open         High          Low        Close  \
# 0     2019-07-25  2619.800049  2666.000000  2607.250000  2654.100098
# 1     2019-07-26  2640.050049  2714.000000  2621.699951  2704.949951
# 2     2019-07-29  2709.899902  2726.800049  2621.300049  2653.949951
# 3     2019-07-30  2648.000000  2693.500000  2549.100098  2560.000000
# 4     2019-07-31  2535.000000  2590.000000  2533.000000  2574.600098
# ...          ...          ...          ...          ...          ...
# 1230  2024-07-19  6660.000000  6718.399902  6626.299805  6636.000000
# 1231  2024-07-22  6580.000000  6780.000000  6580.000000  6770.899902
# 1232  2024-07-23  6770.000000  6884.000000  6717.000000  6865.000000
# 1233  2024-07-24  6938.899902  6938.899902  6793.250000  6820.149902
# 1234  2024-07-25  6795.000000  6874.950195  6757.049805  6853.200195
#
#         Adj Close   Volume
# 0     2571.718262   516388
# 1     2620.989746   537619
# 2     2571.572754   919633
# ...

# %%
fig = px.scatter(df, x='Open', y='Close', labels={'Open': 'X-Axis', 'Close': 'Y-Axis'}, title='Scatter Plot')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# <p style = "font-size:150%; color:#226666">💡 Result </p>
#
#   - <p style = "color:#226666">Here we have a data that is far away from the data collection, which can be due to the following reasons:
# Sudden changes in supply and demand: Factors such as sudden changes in supply or demand can cause sudden changes in prices.
# Sudden changes in market conditions: Market fluctuations and sudden changes in economic conditions may be known as noise.
# Effects of investor decisions: Investor decisions, even if based on correct information, can have unexpected effects.
# For risk management and more accurate analysis, algorithms or statistical analysis methods may need to be applied to the data to separate the noise from the important information.</p>

# %%
fig = px.scatter(df, x='High', y='Close', labels={'Open': 'X-Axis', 'Adj Close': 'Y-Axis'}, title='Scatter Plot')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# <p style = "font-size:150%; color:#226666">💡 Result </p>
#
#   - <p style = "color:#226666">In financial markets, if the trading volume is zero, this may be the result of inactivity or technical problems. This situation usually indicates that there are no transactions at the relevant time or the data of the transaction volume is not available. Various reasons may cause the transaction volume to be zero: Market shutdown: If the financial market is closed at a certain time, the transaction volume may is to reach zero. This usually happens on public holidays or when the market is closed.
# Technical problems: Technical problems in data transmission or loss of transaction information can cause the volume of transactions to reach zero.
# Noise in the data: In some cases, the financial data may contain noise and the trading volume may be set to zero by mistake. This may be the result of data collection errors or problems in data processing. In any case, it is important to take a closer look at what caused zero trading volume to identify the root cause of this situation. If this situation persists for no apparent reason, you may need to contact data sources or systems that provide trading volume data to troubleshoot the problem.
# At high values of 10b, there is also noise and it is far from the place of data accumulation.</p>

# %%
missing_value=len(df.index)-df.count()
missing_value
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1235.000000  1235.000000  1235.000000  1235.000000  1235.000000
# mean   4605.538103  4654.537455  4551.540964  4601.342511  4520.800522
# std     954.552719   957.853014   947.190992   952.548891   965.323785
# min    2500.000000  2526.899902  2351.199951  2492.550049  2415.182617
# 25%    4187.475098  4249.550049  4155.350098  4207.150147  4132.927735
# 50%    4560.049805  4610.799805  4508.000000  4556.250000  4476.674316
# 75%    5248.000000  5292.949951  5179.074951  5229.250000  5122.400390
# max    6938.899902  6938.899902  6793.250000  6865.000000  6865.000000
#
#              Volume
# count  1.235000e+03
# mean   7.398023e+05
# std    1.014370e+06
# min    2.083600e+04
# 25%    3.161825e+05
# 50%    4.887780e+05
# 75%    8.274460e+05
# max    2.198708e+07

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots


fig = make_subplots(rows=2, cols=3, subplot_titles=['Open', 'Close', 'High', 'Low'])


fig.add_trace(go.Scatter(x=df['Open'], y=df['Adj Close'], mode='lines+markers', name='Open'), row=1, col=1)
fig.add_trace(go.Scatter(x=df['Close'], y=df['Adj Close'], mode='lines+markers', name='Close'), row=1, col=2)
fig.add_trace(go.Scatter(x=df['High'], y=df['Adj Close'], mode='lines+markers', name='High'), row=2, col=1)
fig.add_trace(go.Scatter(x=df['Low'], y=df['Adj Close'], mode='lines+markers', name='Low'), row=2, col=2)
fig.add_trace(go.Scatter(x=df['Low'], y=df['Adj Close'], mode='lines+markers', name='Low'), row=2, col=2)
fig.add_trace(go.Scatter(x=df['Volume'], y=df['Adj Close'], mode='lines+markers', name='Low'), row=1, col=3)

fig.update_layout(title_text='Financial Data', showlegend=False)

fig.update_yaxes(title_text='Adj Close', row=1, col=1)
fig.update_yaxes(title_text='Adj Close', row=2, col=1)
fig.update_yaxes(title_text='Adj Close', row=2, col=2)
fig.update_yaxes(title_text='Adj Close', row=1, col=2)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
fig = px.line(df, x='Date', y='Adj Close')
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %% [markdown]
# <p style = "font-size:150%; color:#226666">💡 Result </p>
#
#   - <p style = "color:#226666">It has fallen and then grown again strongly. This pattern of market behavior may occur at different times for different reasons. In financial analysis, these developments can be studied using different tools and methods. In general, market patterns and trends may be better identified using linear and statistical analysis.
# Some of the most common methods and tools for analyzing the Close behavior of a data in the financial market are:
# Technical Analysis: This method includes the use of charts, indicators and different patterns to analyze the price chart. Indicators such as moving averages, RSI (relative strength index), and MACD (moving average divergence) may be used in this method.
# Fundamental Analysis: This method examines the economic, financial, and performance factors of companies. You can refer to financial data related to the desired company, such as profit, revenue, and related financial market news.
# Psychological Analysis: Examining the emotional and behavioral factors of investors can also help to better understand market developments.
# The most important point is that each financial market data has its unique situations and characteristics, and for accurate analysis, a deep understanding and a combination of these methods are required.</p>

# %%
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
fig = px.line(df, x='Date', y='Close')
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %% [markdown]
# <p style = "font-size:150%; color:#226666">💡 Result </p>
#
#   - <p style = "color:#226666">It has fallen and then grown again strongly. This pattern of market behavior may occur at different times for different reasons. In financial analysis, these developments can be studied using different tools and methods. In general, market patterns and trends may be better identified using linear and statistical analysis.
# Some of the most common methods and tools for analyzing the Close behavior of a data in the financial market are:
# Technical Analysis: This method includes the use of charts, indicators and different patterns to analyze the price chart. Indicators such as moving averages, RSI (relative strength index), and MACD (moving average divergence) may be used in this method.
# Fundamental Analysis: This method examines the economic, financial, and performance factors of companies. You can refer to financial data related to the desired company, such as profit, revenue, and related financial market news.
# Psychological Analysis: Examining the emotional and behavioral factors of investors can also help to better understand market developments.
# The most important point is that each financial market data has its unique situations and characteristics, and for accurate analysis, a deep understanding and a combination of these methods are required.</p>

# %%
dff=df.copy()

# %%
# dff['Date'] = pd.to_datetime(dff['Date'], errors='coerce')
dff['Date'] = pd.to_datetime(dff['Date'], format=format)

# %%
dff
# Out:
#            Date         Open         High          Low        Close  \
# 0    2019-07-25  2619.800049  2666.000000  2607.250000  2654.100098
# 1    2019-07-26  2640.050049  2714.000000  2621.699951  2704.949951
# 2    2019-07-29  2709.899902  2726.800049  2621.300049  2653.949951
# 3    2019-07-30  2648.000000  2693.500000  2549.100098  2560.000000
# 4    2019-07-31  2535.000000  2590.000000  2533.000000  2574.600098
# ...         ...          ...          ...          ...          ...
# 1230 2024-07-19  6660.000000  6718.399902  6626.299805  6636.000000
# 1231 2024-07-22  6580.000000  6780.000000  6580.000000  6770.899902
# 1232 2024-07-23  6770.000000  6884.000000  6717.000000  6865.000000
# 1233 2024-07-24  6938.899902  6938.899902  6793.250000  6820.149902
# 1234 2024-07-25  6795.000000  6874.950195  6757.049805  6853.200195
#
#         Adj Close   Volume
# 0     2571.718262   516388
# 1     2620.989746   537619
# 2     2571.572754   919633
# 3     2480.538818  2197242
# ...

# %%
print(dff['Date'].dtype)
# Out:
# datetime64[ns]

# %%
dff['Year'] = dff['Date'].dt.year
dff['Month'] = dff['Date'].dt.month
dff['Day'] = dff['Date'].dt.day

# %%
sns.set_theme(style="ticks")
plt.suptitle('Market')
sns.pairplot(df)

# %% [markdown]
# <p style = "font-size:150%; color:#226666">💡 Result </p>
#
#   - <p style = "color:#226666">If all columns in a dataframe are ascending and also have a positively skewed distribution, this may indicate a tendency for larger values and more scatter in the data.
# The skewness distribution indicates the symmetry or asymmetry of the data. A positively skewed distribution indicates that the data tends toward values larger than the mean. Considering these things, we can do the following analysis:
# Tendency to grow: Larger and ascending values indicate a tendency to grow and increase. This may indicate positive trends in the market or variables under consideration.
# Greater dispersion: A positively skewed distribution indicates greater dispersion in the data. This can mean large differences between different values and more volatility.
# Risk and different positions: These features can indicate high risk or different positions in the market. People may invest more than risk and return analyzes in this situation.
# Potential for high returns or high losses: the presence of a tendency for larger amounts and greater dispersion may represent potential</p>

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['Adj Close'], kde=True, bins=10, color='green')
plt.title('Return probability distribution chart')
plt.xlabel('Returns')
plt.ylabel('Number')
plt.show()

# %% [markdown]
# <p style = "font-size:150%; color:#226666">💡 Result </p>
#
#   - <p style = "color:#226666">If all columns in a dataframe are ascending and also have a positively skewed distribution, this may indicate a tendency for larger values ​​and more scatter in the data.The skewness distribution indicates the symmetry or asymmetry of the data. A positively skewed distribution indicates that the data tends toward values ​​larger than the mean. Considering these things, we can do the following analysis
# which means the sudden growth of these stocks</p>

# %%
month_names = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# %%
a=[]
for i in dff['Month']:
    if i==1:
        a.append(month_names[0])
    elif i==2:
        a.append(month_names[1])
    elif i==3:
        a.append(month_names[2])
    elif i==4:
        a.append(month_names[3])
    elif i==5:
        a.append(month_names[4])
    elif i==6:
        a.append(month_names[5])
    elif i==7:
        a.append(month_names[6])
    elif i==8:
        a.append(month_names[7])
    elif i==9:
        a.append(month_names[8])
    elif i==10:
        a.append(month_names[9])
    elif i==11:
        a.append(month_names[10])
    elif i==12:
        a.append(month_names[11])

# %%
dff['Month Names']=a

# %%
dff
# Out:
#            Date         Open         High          Low        Close  \
# 0    2019-07-25  2619.800049  2666.000000  2607.250000  2654.100098
# 1    2019-07-26  2640.050049  2714.000000  2621.699951  2704.949951
# 2    2019-07-29  2709.899902  2726.800049  2621.300049  2653.949951
# 3    2019-07-30  2648.000000  2693.500000  2549.100098  2560.000000
# 4    2019-07-31  2535.000000  2590.000000  2533.000000  2574.600098
# ...         ...          ...          ...          ...          ...
# 1230 2024-07-19  6660.000000  6718.399902  6626.299805  6636.000000
# 1231 2024-07-22  6580.000000  6780.000000  6580.000000  6770.899902
# 1232 2024-07-23  6770.000000  6884.000000  6717.000000  6865.000000
# 1233 2024-07-24  6938.899902  6938.899902  6793.250000  6820.149902
# 1234 2024-07-25  6795.000000  6874.950195  6757.049805  6853.200195
#
#         Adj Close   Volume  Year  Month  Day Month Names
# 0     2571.718262   516388  2019      7   25        July
# ...

# %%
fig = px.bar(dff, x='Month Names', y='Adj Close')
fig.show()
# Out:
# <div>                            <div id="b5804fa9-f3c5-4d54-8141-8e9fc5fd8fe2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b5804fa9-f3c5-4d54-8141-8e9fc5fd8fe2")) {                    Plotly.newPlot(                        "b5804fa9-f3c5-4d54-8141-8e9fc5fd8fe2",                        [{"alignmentgroup":"True","hovertemplate":"Month Names=%{x}\u003cbr\u003eAdj Close=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["July","July","July","July","July","August","August","August","August","August","August","August","August","August","August","August","August","August","August","August","August",
# ...

# %% [markdown]
# <p style = "font-size:150%; color:#226666">💡 Result </p>
#
#   - <p style = "color:#226666">If in certain months, the stock of a company grows more, it can mean a brief meaning that in those months certain conditions for the positive performance of the company have arisen. But for a more accurate interpretation and providing different points of view, you should pay attention to several points:
# Invoices for specific months: A detailed review of invoices for specific months can be helpful. These factors may include national or international events (such as economic calendar, financial report announcement, industry news, etc.) or even technical and analytical factors.
# Market trends: It is also important to review the general view of the market. If the shares of many companies are higher in a month, it may be due to general market trends.
# Periodic or seasonal growth: Some industries and companies are affected by certain seasons or periods. Investigating whether this growth in specific months can be recognized as a periodic or seasonal pattern can provide more information.
# The most important factors: It is important to know the most important factors that affect growth. This may include agents</p>

# %%
fig = px.bar(dff, x='Day', y='Adj Close')
fig.show()
# Out:
# <div>                            <div id="d5808d8c-fce2-400f-acd5-725bae9f7d87" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d5808d8c-fce2-400f-acd5-725bae9f7d87")) {                    Plotly.newPlot(                        "d5808d8c-fce2-400f-acd5-725bae9f7d87",                        [{"alignmentgroup":"True","hovertemplate":"Day=%{x}\u003cbr\u003eAdj Close=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[25,26,29,30,31,1,2,5,6,7,8,9,13,14,16,19,20,21,22,23,26,27,28,29,30,3,4,5,6,9,11,12,13,16,17,18,19,20,23,24,25,26,27,30,1,3,4,7,9,10,11,14,15,16,17,18,22,23,24,25,27,29,30,31,1,4,5,6,7,8,
# ...

# %%
pivot_table = dff.pivot_table(values='Adj Close', index='Month Names', columns='Day')
plt.figure(figsize=(40, 20))


heatmap=sns.heatmap(pivot_table, annot=True, fmt=".0f")

plt.yticks(rotation=0)
plt.xlabel('Month')
plt.ylabel('Year')
plt.title('Heatmap of Close based on Year and Month')
plt.show()

# %% [markdown]
# <p style = "font-size:150%; color:#226666">💡 Result </p>
#
#   - <p style = "color:#226666">If the colors are mostly purple and yellow in the heatmap you made based on months and days, it may indicate several points:
# Broad Market Activity: If purple and yellow colors represent broad activity in the financial markets, this could indicate more investor activity on these dates. These days may have important news and events.
# Seasonal or periodic changes: Seasonal or periodic changes in the financial market may cause color differences.
# Calendar fluctuations: There may be calendar fluctuations or certain patterns in the behavior of the markets on certain days of the month and day.
# Economic or political developments: Changes in the economy or political events can have an impact and create color differences in the heatmap.</p>

# %%
pivot_table = dff.pivot_table(values='Adj Close', index='Month Names', columns='Year')
plt.figure(figsize=(40, 20))


heatmap=sns.heatmap(pivot_table, annot=True, fmt=".0f")

plt.yticks(rotation=0)
plt.xlabel('Month')
plt.ylabel('Year')
plt.title('Heatmap of Close based on Year and Month')
plt.show()

# %% [markdown]
# <p style = "font-size:150%; color:#226666">💡 Result </p>
#
#   - <p style = "color:#226666">The heatmap color change from purple to yellow in most cases may indicate positive developments in the financial markets, but it should be noted that more information and deeper analysis is needed for a more accurate and definitive interpretation. These positive developments can be related to measuring the following:
# Economic growth: An increase in color from purple to yellow may indicate economic growth and increased economic activity in the financial markets.
# Positive effects of news: Positive news such as the announcement of successful financial reports, related industry news or positive agreements can lead to positive developments in the heatmap.
# Increasing investor confidence: If the color change from purple to yellow indicates increasing investor confidence, this could indicate less concern and a strengthening market.
# Positive structural developments: changes in the market structure, new laws or other structural developments may be related to positive developments in the heatmap.</p>

# %%
pct=dff['Adj Close'].pct_change()
pct.plot(legend=True,grid=True)
# Out:
# <Axes: >

# %%
dff['PCT']=pct

# %%
dff.plot(x='Year', y='PCT', kind='line', figsize=(10, 6), grid=True, legend=True)

plt.title('Percentage Change of Close Over Years')
plt.xlabel('Year')
plt.ylabel('Percentage Change')
plt.show()

# %% [markdown]
# <p style = "font-size:150%; color:#226666">💡 Result </p>
#
#   - <p style = "color:#226666">Percentage changes in prices (such as the pct value you created) show the ratio of price change over a specific time period relative to the previous price. It is commonly used to measure volatility and market movements. A positive percentage change indicates an increase in price, while a negative percentage change indicates a decrease in price.</p>

# %%
fig = go.Figure(data=go.Ohlc(x=dff['Date'],
                open=dff['Open'],
                high=dff['High'],
                low=dff['Low'],
                close=dff['Close']))

fig.update_layout(
    title='The BOOM',
    yaxis_title='DRREDDY Stock'
)

fig.show()
# Out:
# <div>                            <div id="17dcf2fe-0794-4f0e-969b-355068adf265" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("17dcf2fe-0794-4f0e-969b-355068adf265")) {                    Plotly.newPlot(                        "17dcf2fe-0794-4f0e-969b-355068adf265",                        [{"close":[2654.100098,2704.949951,2653.949951,2560.0,2574.600098,2533.75,2529.199951,2514.699951,2556.199951,2556.800049,2571.949951,2573.449951,2556.350098,2511.949951,2492.550049,2509.100098,2554.600098,2503.0,2545.399902,2541.25,2567.199951,2540.699951,2512.100098,2527.800049,2557.5,2532.800049,2602.699951,2682.449951,2739.949951,2749.199951,2761.0,2767.050049,2731.550049,2725.300049,2738.050049,2743.649902,2732.550049,2837.800049,2767.25,2785.25,2773.350098,2
# ...

# %%
#EMA
dff['EMA_9'] = dff['Close'].ewm(9).mean().shift()
dff['EMA_22'] = dff['Close'].ewm(22).mean().shift()
#SMA
dff['SMA_5'] = dff['Close'].rolling(5).mean().shift()
dff['SMA_10'] = dff['Close'].rolling(10).mean().shift()
dff['SMA_15'] = dff['Close'].rolling(15).mean().shift()
dff['SMA_30'] = dff['Close'].rolling(30).mean().shift()
#RSI14
def RSI(dff, n=14):
    close = dff['Close']
    delta = close.diff()
    delta = delta[1:]
    pricesUp = delta.copy()
    pricesDown = delta.copy()
    pricesUp[pricesUp < 0] = 0
    pricesDown[pricesDown > 0] = 0
    rollUp = pricesUp.rolling(n).mean()
    rollDown = pricesDown.abs().rolling(n).mean()
    rs = rollUp / rollDown
    rsi = 100.0 - (100.0 / (1.0 + rs))
    return rsi

dff['RSI'] = RSI(dff).fillna(0)

EMA_12 = pd.Series(dff['Close'].ewm(span=12, min_periods=12).mean())
EMA_26 = pd.Series(dff['Close'].ewm(span=26, min_periods=26).mean())
dff['MACD'] = pd.Series(EMA_12 - EMA_26)
dff['MACD_signal'] = pd.Series(dff.MACD.ewm(span=9, min_periods=9).mean())

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=dff.Date, y=dff.EMA_9, name='EMA 9 Day'))
fig.add_trace(go.Scatter(x=dff.Date, y=dff.EMA_22, name='EMA 22 Day'))
fig.add_trace(go.Scatter(x=dff.Date, y=dff.SMA_5, name='SMA 5 Day'))
fig.add_trace(go.Scatter(x=dff.Date, y=dff.SMA_10, name='SMA 10 Day'))
fig.add_trace(go.Scatter(x=dff.Date, y=dff.SMA_15, name='SMA 15 Day'))
fig.add_trace(go.Scatter(x=dff.Date, y=dff.SMA_30, name='SMA 30 Day'))
fig.add_trace(go.Scatter(x=dff.Date, y=dff.Close, name='Close', opacity=0.3))
fig.update_layout(
    title='The BOOM',
    yaxis_title='DRREDDY Stock'
)
fig.show()
# Out:
# <div>                            <div id="de44cc34-abaa-46e9-95ef-0221b20a2c82" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("de44cc34-abaa-46e9-95ef-0221b20a2c82")) {                    Plotly.newPlot(                        "de44cc34-abaa-46e9-95ef-0221b20a2c82",                        [{"name":"EMA 9 Day","x":["2019-07-25T00:00:00","2019-07-26T00:00:00","2019-07-29T00:00:00","2019-07-30T00:00:00","2019-07-31T00:00:00","2019-08-01T00:00:00","2019-08-02T00:00:00","2019-08-05T00:00:00","2019-08-06T00:00:00","2019-08-07T00:00:00","2019-08-08T00:00:00","2019-08-09T00:00:00","2019-08-13T00:00:00","2019-08-14T00:00:00","2019-08-16T00:00:00","2019-08-19T00:00:00","2019-08-20T00:00:00","2019-08-21T00:00:00","2019-08-22T00:00:00","2019-08-23T00:00:00","2
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=dff.Date, y=dff.EMA_22, name='EMA 22 Day'))
fig.update_layout(
    title='EMA 22 Day',
    yaxis_title='DRREDDY Stock'
)
fig.show()
# Out:
# <div>                            <div id="5ed876a4-459f-455e-85f6-91e5d59a0a7f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ed876a4-459f-455e-85f6-91e5d59a0a7f")) {                    Plotly.newPlot(                        "5ed876a4-459f-455e-85f6-91e5d59a0a7f",                        [{"name":"EMA 22 Day","x":["2019-07-25T00:00:00","2019-07-26T00:00:00","2019-07-29T00:00:00","2019-07-30T00:00:00","2019-07-31T00:00:00","2019-08-01T00:00:00","2019-08-02T00:00:00","2019-08-05T00:00:00","2019-08-06T00:00:00","2019-08-07T00:00:00","2019-08-08T00:00:00","2019-08-09T00:00:00","2019-08-13T00:00:00","2019-08-14T00:00:00","2019-08-16T00:00:00","2019-08-19T00:00:00","2019-08-20T00:00:00","2019-08-21T00:00:00","2019-08-22T00:00:00","2019-08-23T00:00:00","
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=dff.Date, y=dff.SMA_10, name='SMA 10 Day'))
fig.update_layout(
    title='SMA 10 Day',
    yaxis_title='DRREDDY Stock'
)
fig.show()
# Out:
# <div>                            <div id="f0e916e6-5212-4474-adc0-9d492eeeb355" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f0e916e6-5212-4474-adc0-9d492eeeb355")) {                    Plotly.newPlot(                        "f0e916e6-5212-4474-adc0-9d492eeeb355",                        [{"name":"SMA 10 Day","x":["2019-07-25T00:00:00","2019-07-26T00:00:00","2019-07-29T00:00:00","2019-07-30T00:00:00","2019-07-31T00:00:00","2019-08-01T00:00:00","2019-08-02T00:00:00","2019-08-05T00:00:00","2019-08-06T00:00:00","2019-08-07T00:00:00","2019-08-08T00:00:00","2019-08-09T00:00:00","2019-08-13T00:00:00","2019-08-14T00:00:00","2019-08-16T00:00:00","2019-08-19T00:00:00","2019-08-20T00:00:00","2019-08-21T00:00:00","2019-08-22T00:00:00","2019-08-23T00:00:00","
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=dff.Date, y=dff.SMA_30, name='SMA 30 Day'))
fig.update_layout(
    title='The BOOM',
    yaxis_title='DRREDDY Stock'
)
fig.show()
# Out:
# <div>                            <div id="f9c3680a-b85c-45a7-9bf3-f9a031fce8c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f9c3680a-b85c-45a7-9bf3-f9a031fce8c3")) {                    Plotly.newPlot(                        "f9c3680a-b85c-45a7-9bf3-f9a031fce8c3",                        [{"name":"SMA 30 Day","x":["2019-07-25T00:00:00","2019-07-26T00:00:00","2019-07-29T00:00:00","2019-07-30T00:00:00","2019-07-31T00:00:00","2019-08-01T00:00:00","2019-08-02T00:00:00","2019-08-05T00:00:00","2019-08-06T00:00:00","2019-08-07T00:00:00","2019-08-08T00:00:00","2019-08-09T00:00:00","2019-08-13T00:00:00","2019-08-14T00:00:00","2019-08-16T00:00:00","2019-08-19T00:00:00","2019-08-20T00:00:00","2019-08-21T00:00:00","2019-08-22T00:00:00","2019-08-23T00:00:00","
# ...

# %% [markdown]
# <p style = "font-size:150%; color:#226666">💡 Result </p>
#
#   - <p style = "color:#226666">Moving average is one of the basic concepts in technical analysis and is widely used in financial markets. This concept helps in analyzing price patterns and trends. Moving averages are usually divided into two types: simple moving average (SMA) and exponential moving average (EMA).
# Simple Moving Average (SMA):
# In SMA, to calculate the average, the prices are considered equally and without weight priority.
# To calculate the SMA with a time window n, we add the prices of the previous n periods and divide by their number.
# Exponential Moving Average (EMA):
# In the EMA, new prices are given more weight. This means that more recent prices are given more weight in the calculation of the average.
# A regression relation is used to calculate the EMA with an n time window.
# A moving average is used as an indicator of changes in price trends. In technical analysis, the comparison of moving averages with the current price or with each other can be interpreted as buy or sell signals. For example, if the price crosses above the SMA, this may be interpreted as a buy signal.
# If the SMA (Simple Moving Average) chart is moving up, it can mean several things and depends on the market context and time period under consideration. In technical analysis, the upward movement of the SMA is one of the indicators of the strength of the market's upward trend. In this scenario, you can consider it as a positive signal.
# Here are some possible interpretations for the upward movement of the SMA:
# The strength of the upward trend:
# If the SMA moves up, it is an indication of the strength of the market's uptrend. This may indicate that the average prices have increased over a certain time period (eg 5, 10, 50 days) and that prices are generally moving in an upward direction.
# Motion stability:
# An upward movement of the SMA may indicate trend persistence, meaning that prices are continuing to rise and this movement is likely to continue for some time.
# Buy signal:
# Some traders interpret the upward SMA as a buy signal. This may mean that the market is strengthening and prices may move positively.
# Now, you should note that any analysis should be done carefully with additional information and decisions should be made based on market conditions and existing risks. Also, using other indicators and analytical tools along with SMA can improve decision making.
# Examining the simple moving average (SMA) in different time frames plays an important role in the technical analysis of financial markets. Using SMA with different timeframes means the following:
# 9-day SMA:
# SMA with this timeframe usually represents a short-term trend and is more sensitive to price changes. As a result, this SMA performs best in detecting rapid price changes and identifying entry and exit points for short-term investment positions.
# 22-day SMA:
# SMA with this timeframe is suitable for displaying medium-term trends and detecting medium-term price changes. This may be useful for investors looking for medium-term entry and exit analysis.
# By using SMA with different timeframes, investors can identify strengths and weaknesses in price trends and make decisions based on technical analysis tailored to your own investment goals and style. Also, using multiple SMAs with different timeframes as "twin peaks" is also used to confirm signals
# If the Simple Moving Average (SMA) and the Exponential Moving Average (EMA) are close together and similar on a chart, this may indicate a convergence in the price trend. This situation may mean confirmation of the market trend.
# Some traders and analysts use congruence between moving averages as a sign of trend strength and continuity. This means that if both types of moving averages move close to each other, it confirms that the price trend is ongoing and short-term changes may be small and If the Simple Moving Average (SMA) and the Exponential Moving Average (EMA) both appear to be moving close to each other and moving in the same direction (up or down) at the same time, it can indicate strength and confirmation of the market trend. When both types of moving averages (SMA and EMA) are moving upward in general, this may indicate strengthening price action and confirm the market's bullish trend. This situation can be considered by traders as the point of entering the buying position (Long)..</p>

# %%
import plotly.graph_objects as go


fig = go.Figure()


fig.add_trace(go.Scatter(x=dff['Date'], y=dff['RSI'], name='RSI'))


fig.add_shape(
    go.layout.Shape(
        type="line",
        x0=dff['Date'].iloc[0],
        x1=dff['Date'].iloc[-1],
        y0=30,
        y1=30,
        line=dict(color="red", width=2, dash="dash"),
    )
)

fig.add_shape(
    go.layout.Shape(
        type="line",
        x0=dff['Date'].iloc[0],
        x1=dff['Date'].iloc[-1],
        y0=70,
        y1=70,
        line=dict(color="red", width=2, dash="dash"),
    )
)


fig.show()
# Out:
# <div>                            <div id="1e52f401-11a9-4d47-bde8-b9002bbf9524" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1e52f401-11a9-4d47-bde8-b9002bbf9524")) {                    Plotly.newPlot(                        "1e52f401-11a9-4d47-bde8-b9002bbf9524",                        [{"name":"RSI","x":["2019-07-25T00:00:00","2019-07-26T00:00:00","2019-07-29T00:00:00","2019-07-30T00:00:00","2019-07-31T00:00:00","2019-08-01T00:00:00","2019-08-02T00:00:00","2019-08-05T00:00:00","2019-08-06T00:00:00","2019-08-07T00:00:00","2019-08-08T00:00:00","2019-08-09T00:00:00","2019-08-13T00:00:00","2019-08-14T00:00:00","2019-08-16T00:00:00","2019-08-19T00:00:00","2019-08-20T00:00:00","2019-08-21T00:00:00","2019-08-22T00:00:00","2019-08-23T00:00:00","2019-08
# ...

# %% [markdown]
# <p style = "font-size:150%; color:#226666">💡 Result </p>
#
#   - <p style = "color:#226666">If the RSI is mostly above 70, this means that the asset or market may be in an "overbought" condition. This situation indicates that the market is overbought and there may be sell-off pressure in the future. A combination of strong price growth and a high RSI may indicate that prices have risen unreasonably and without basis, and that a decline is likely in the future.However, one should always perform technical analysis carefully and use other available indicators and information. Also, it should be noted that the RSI may stay in the "overbought" zone for a long time in strong markets and prices continue to move higher. For this reason, analysis along with other signs and symptoms will be more useful.</p>

# %%
# 7-Day Moving Average
dff['MA_7'] = dff['Adj Close'].rolling(window=7).mean()

# 14-Day Moving Average
dff['MA_14'] = dff['Adj Close'].rolling(window=14).mean()

fig, (ax1, ax2, ax3) = plt.subplots(3, 1, sharex=True, figsize=(10, 8))

# Subplot 1: Stock Price
ax1.plot(dff['Date'], dff['Adj Close'], label='Stock Price', marker='o', color='blue')
ax1.set_ylabel('Adj Close')
ax1.legend()

# Subplot 2: 7-Day Moving Average
ax2.plot(dff['Date'], dff['MA_7'], label='7-Day Moving Average', linestyle='--', marker='o', color='green')
ax2.set_ylabel('MA_7')
ax2.legend()

# Subplot 3: 14-Day Moving Average
ax3.plot(dff['Date'], dff['MA_14'], label='14-Day Moving Average', linestyle='--', marker='o', color='red')
ax3.set_xlabel('Date')
ax3.set_ylabel('MA_14')
ax3.legend()

# Overall Title
plt.suptitle('Moving Average Chart')
plt.show()

# %% [markdown]
# <p style = "font-size:150%; color:#226666">💡 Result </p>
#
#   - <p style = "color:#226666">Upward Sloping Moving Average Chart means the use of moving average in an ascending or growing way in the price chart of an asset. Ascending moving average is used as a technical analysis indicator to examine the general trend of price movement and show the trend average.When an ascending moving average is displayed as an upward trend, it means an uptrend in the market. This may indicate a possible strengthening of the demand for purchased components, and the ascending moving average may be used as a buy signal.The longer the moving average becomes longer, the more likely the upward trend will continue. This could indicate strong market power. However, it should always be used with other indicators and verified information rather than analysis If the moving averages are the same for two different time frames, say 7 days and 14 days, this can mean a congruence in the price trend. In technical analysis, moving averages are commonly used to identify general market trends and filter out short-term fluctuations.With the same 7-day and 14-day moving averages, this indicates that the price trend in the two different time frames is almost the same. This may mean stability in the market trend, no significant change in the price movement trend, or coordination between short-term volatility and long-term volatility.</p>

# %%
# Calculate the 20-day moving average
dff['MA_20'] = dff['Adj Close'].rolling(window=20).mean()

# Calculate the 20-day standard deviation
dff['Upper_Band'] = dff['MA_20'] + 2 * dff['Adj Close'].rolling(window=20).std()
dff['Lower_Band'] = dff['MA_20'] - 2 * dff['Adj Close'].rolling(window=20).std()


fig, (ax1, ax2,ax3) = plt.subplots(3, 1, sharex=True, figsize=(10, 8))


ax1.plot(dff['Date'], dff['Adj Close'], label='Stock Price', marker='o')
ax1.set_ylabel('Adj Close')
ax1.legend()
ax2.plot(dff['Date'], dff['MA_20'], label='20-Day Moving Average', linestyle='--', marker='o', color='green')
ax2.set_ylabel('Adj Close')
ax2.legend()


ax3.plot(dff['Date'], dff['Upper_Band'], label='Upper Bollinger Band', linestyle='--', color='green')
ax3.plot(dff['Date'], dff['Lower_Band'], label='Lower Bollinger Band', linestyle='--', color='red')
ax3.set_xlabel('Date')
ax3.set_ylabel('Bollinger Bands')
ax3.legend()

plt.suptitle('Bollinger Bands Chart with Subplots')
plt.show()

# %% [markdown]
# <p style = "font-size:150%; color:#226666">💡 Result </p>
#
#   - <p style = "color:#226666">Bollinger Bands are commonly used as a tool to analyze and identify buy or sell situations in the market. When the price approaches or crosses the upper band, the market may be recognized as "overbought" and the price is likely to decline in the future. Similarly, when the price approaches or crosses the lower band, the market may be recognized as "oversold" and the price is likely to rise in the future.</p>
